# %%
from rag_helper import RAGBase

# %%
from ingest import load_faq_data, build_index

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os

# %%
from groq import Groq
client = Groq(api_key=os.getenv("GROQ_API_KEY"))

# %%
documents= load_faq_data()
index = build_index(documents)

assistant = RAGBase(index, client)

# %%
assistant.rag("I just discovered the course, can I still join?")
# Out:
# "Yes, you can still join the course. Although you've just discovered it, you can still participate, even if you've missed any of the initial material. However, keep in mind that there may be certain criteria you need to meet to receive a certificate, such as submitting your project while the course form is still open and passing the Capstone project."
